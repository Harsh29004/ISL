# %%
import os

root = "ISL_CSLRT_Corpus/Frames_Word_Level"

classes = os.listdir(root)

print("Total words:", len(classes))
print("Example words:", classes[:10])
# Out:
# Total words: 114
# Example words: ['A LOT', 'ABUSE', 'AFRAID', 'AGREE', 'ALL', 'ANGRY', 'ANYTHING', 'APPRECIATE', 'BAD', 'BEAUTIFUL']
